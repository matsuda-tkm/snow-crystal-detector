# %% [markdown]
# ## RandomForestによる、切り出し済み画像に対する分類
#
# 1. 切り出し済み画像のパスを取得してリストに格納する（`dataset.zip`を解凍した`dataset/`配下のファイル名）
#     - 注）評価データの順序が揃うように、YOLO学習時と同じ順序で格納する
# 2. sklearn.model_selection の StratifiedKFold を用いる (n_splits=5)
#     - 引数には全画像のパスとラベルのリストを指定する
#     - 注）`random_state`を指定して、同じ結果を得られるようにする
# 4. Fold数ぶんのfor文を回して下記を行う
#    - StratifiedKFold で生成された index を用いてデータをtrain, testに分割する
#    - 分割したデータを用いてランダムフォレストの学習を行う
#    - 学習したモデルを用いてテストデータの予測を行う
# 5. 各Foldにおけるテストデータの予測結果を集計して混同行列を作成する
